# %% [markdown]
# # 1-IMPORTANDO BIBLIOTECAS

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2- CARREGANDO E VISUALIZANDO O DATASET

# %%
arquivo = pd.read_pickle('C:/excel/Candidatos/base_treinamento_testes.pkl')

# %%
arquivo.head()

# %% [markdown]
# # 3-EXCLUINDO AS TABELAS

# %%
arquivo.drop('ultimo_cargo_candidato', axis=1, inplace=True)
arquivo.drop('area_interesse_candidato', axis =1, inplace=True)
arquivo.drop('mediana_teste_ingles_candidato', axis =1, inplace=True)
arquivo.drop('mediana_teste_espanhol_candidato', axis =1, inplace=True)
arquivo.drop('cidade_vaga', axis=1, inplace=True)

# %% [markdown]
# # 4-OBTENDO INFORMAÇÂO DOS ARQUIVOS

# %%
arquivo.info()

# %% [markdown]
# # 5-VERIFICA A QUANTIDADE DE NUMEROS FALTANTES

# %%
faltantes =arquivo.isnull().sum()
print(faltantes)

# %% [markdown]
# # 6-TRATANDO OS NUMEROS FALTANTES

# %% [markdown]
# # 6.1- TRATATANDO COLUNA VIVEL_CANDIDATO

# %%
arquivo['nivel_candidato'].value_counts()

# %%
arquivo['nivel_candidato'] = arquivo['nivel_candidato'].fillna('JUNIOR/TRAINEE')

# %% [markdown]
# # 6.2- TRATATANDO COLUNA CARGO_VAGA

# %%
# 1. Dicionário de padronização (customize conforme necessário)
mapeamento = {
    'PROGRAMA TRAINEE': 'TRAINEE',
    'INTERNACIONAL TRAINEE': 'TRAINEE', 
    'TELECOMUNICACAO TRAINEE': 'TRAINEE',
    'GERENTE LOJA SUPERMERCADO': 'GERENTE',
    'COMERCIAL': 'ANALISTA COMERCIAL',
    'PROGRAMMER': 'ANALISTA DE TI'
}

# 2. Substituição DIRETA na coluna original
arquivo['cargo_vaga'] = (
    arquivo['cargo_vaga']
    .replace(mapeamento)
    .str.upper()  # Padroniza para maiúsculas
    .str.strip()  # Remove espaços extras
)

# %%
arquivo['cargo_vaga'].value_counts()

# %%
arquivo['cargo_vaga'] = arquivo['cargo_vaga'].fillna('TRAINEE')

# %% [markdown]
# # 7 PADRONIZANDO OS DADOS

# %% [markdown]
# # 7.1 PADRONIZANDO O CODIGO_VAGA

# %%
arquivo['codigo_vaga'].value_counts()

# %%
# Substitui 'codigo_vaga' pelos IDs sequenciais (1, 2, 3...)
arquivo['codigo_vaga'] = pd.factorize(arquivo['codigo_vaga'])[0] + 1

# Verifica o resultado
print(arquivo['codigo_vaga'].value_counts().head(16))

# %% [markdown]
# # 8 Padronizando ultimo salario

# %%
pd.set_option('display.max_rows', None)  # Remove o limite de linhas exibidas
print(arquivo['ultimo_salario_candidato'].value_counts())

# %%
# Definir os intervalos das faixas e os rótulos (números inteiros)
bins = [0, 1200, 2000, 3000, 5000, 10000, 20000, 50000, float('inf')]
labels = [1, 2, 3, 4, 5, 6, 7, 8]  # Números inteiros sequenciais

# Substituir a coluna original pelos códigos das faixas
arquivo['ultimo_salario_candidato'] = pd.cut(
    arquivo['ultimo_salario_candidato'],
    bins=bins,
    labels=labels,
    right=False  # Opção para incluir o limite inferior (ex: 1200 entra na faixa 2)
).astype(int)  # Converter para inteiro

# %% [markdown]
# # 9 Padronizando o nivel candidato

# %%
 arquivo['nivel_candidato'].value_counts()

# %%
arquivo['nivel_candidato'] = arquivo['nivel_candidato'].replace('JUNIOR/TRAINEE', 1)
arquivo['nivel_candidato'] = arquivo['nivel_candidato'].replace('ESTAGIO', 2)
arquivo['nivel_candidato'] = arquivo['nivel_candidato'].replace('PLENO', 3)
arquivo['nivel_candidato'] = arquivo['nivel_candidato'].replace('AUXILIAR/OPERACIONAL', 4)
arquivo['nivel_candidato'] = arquivo['nivel_candidato'].replace('SUPERVISAO/COORDENACAO', 5)
arquivo['nivel_candidato'] = arquivo['nivel_candidato'].replace('TECNICO', 6)
arquivo['nivel_candidato'] = arquivo['nivel_candidato'].replace('SENIOR', 7)
arquivo['nivel_candidato'] = arquivo['nivel_candidato'].replace('GERENCIA', 8)
arquivo['nivel_candidato'] = arquivo['nivel_candidato'].replace('DIRETORIA', 9)

# %% [markdown]
#  # 10 Padronizando formacao candidato

# %%
arquivo['formacao_candidato'].value_counts()

# %%
# Grupo 1: Ensino Fundamental e Médio (representado por 1)
arquivo['formacao_candidato'] = arquivo['formacao_candidato'].replace('ENSINO FUNDAMENTAL (1O. GRAU) INTERROMPIDO', 1)
arquivo['formacao_candidato'] = arquivo['formacao_candidato'].replace('ENSINO MEDIO (2O. GRAU) COMPLETO', 1)
arquivo['formacao_candidato'] = arquivo['formacao_candidato'].replace('ENSINO MEDIO (2O. GRAU) PROFISSIONALIZANTE COMPLETO', 1)

# Grupo 2: Ensino Superior (representado por 2)
arquivo['formacao_candidato'] = arquivo['formacao_candidato'].replace('FORMACAO SUPERIOR INTERROMPIDA', 2)
arquivo['formacao_candidato'] = arquivo['formacao_candidato'].replace('FORMACAO SUPERIOR (CURSANDO)', 2)
arquivo['formacao_candidato'] = arquivo['formacao_candidato'].replace('FORMACAO SUPERIOR COMPLETA', 2)

# Grupo 3: Pós-graduação (representado por 3)
arquivo['formacao_candidato'] = arquivo['formacao_candidato'].replace('POS-GRADUACAO NO NIVEL ESPECIALIZACAO', 3)
arquivo['formacao_candidato'] = arquivo['formacao_candidato'].replace('POS-GRADUACAO NO NIVEL MESTRADO', 3)
arquivo['formacao_candidato'] = arquivo['formacao_candidato'].replace('POS-GRADUACAO NO NIVEL DOUTORADO', 3)

# %% [markdown]
# # 11 PADRONIZANDO CIDADE CANDIDATO

# %%
arquivo['cidade_candidato'].value_counts()

# %%
mapeamento_cidades_br_estados = {
    'SAO PAULO': 'SP', 'CAMPINAS': 'SP', 'SAO BERNARDO DO CAMPO': 'SP',
    'SAO JOSE DOS CAMPOS': 'SP', 'SANTO ANDRE': 'SP', 'SANTOS': 'SP',
    'SOROCABA': 'SP', 'OSASCO': 'SP', 'GUARULHOS': 'SP', 'RIBEIRAO PRETO': 'SP',
    'JUNDIAI': 'SP', 'SAO CAETANO DO SUL': 'SP', 'SAO CARLOS': 'SP',
    'PIRACICABA': 'SP', 'AMERICANA': 'SP', 'BARUERI': 'SP', 'MOGI DAS CRUZES': 'SP',
    'LIMEIRA': 'SP', 'JACAREI': 'SP', 'TAUBATE': 'SP', 'DIADEMA': 'SP',
    'INDAIATUBA': 'SP', 'VALINHOS': 'SP', 'BAURU': 'SP', 'SANTANA DE PARNAIBA': 'SP',
    'MAUA': 'SP', 'ARARAQUARA': 'SP', 'ITATIBA': 'SP', 'ITU': 'SP', 'HORTOLANDIA': 'SP',
    'PRAIA GRANDE': 'SP', 'SUMARE': 'SP', 'VINHEDO': 'SP', 'MARILIA': 'SP',
    'EMBU': 'SP', 'MOGI-MIRIM': 'SP', 'BRAGANCA PAULISTA': 'SP', 'ATIBAIA': 'SP',
    'ARUJA': 'SP', 'VOTORANTIM': 'SP', 'RIBEIRAO PIRES': 'SP', 'CUBATAO': 'SP',
    'SERTAOZINHO': 'SP', 'BARRETOS': 'SP', 'PRESIDENTE PRUDENTE': 'SP',
    'JANDIRA': 'SP', 'FERRAZ DE VASCONCELOS': 'SP', 'SAO ROQUE': 'SP',
    'ITAQUAQUECETUBA': 'SP', 'PIRASSUNUNGA': 'SP', 'VOTUPORANGA': 'SP',
    'CAIEIRAS': 'SP', 'ARARAS': 'SP', 'FRANCO DA ROCHA': 'SP',
    'VARZEA PAULISTA': 'SP', 'SAO JOSE DO RIO PARDO': 'SP',
    'ESPIRITO SANTO DO PINHAL': 'SP', 'BARRA BONITA': 'SP', 'MATAO': 'SP',
    'NOVO HORIZONTE': 'SP', 'HOLAMBRA': 'SP', 'OLIMPIA': 'SP', 'ANDRADINA': 'SP',
    'MONTE ALTO': 'SP', 'TANABI': 'SP', 'MAIRIPORA': 'SP', 'PARAGUACU PAULISTA': 'SP',
    'AMPARO': 'SP', 'LENCOIS PAULISTA': 'SP', 'SINOP': 'MT', 'BEBEDOURO': 'SP',
    'BIRIGUI': 'SP', 'SAO PEDRO': 'SP', 'PORTO FERREIRA': 'SP',
    'CAMPO LIMPO PAULISTA': 'SP', 'ITAPECERICA DA SERRA': 'SP',
    'ILHA SOLTEIRA': 'SP', 'ITANHAEM': 'SP', 'POTIRENDABA': 'SP',
    'TIETE': 'SP', 'SANTA FE DO SUL': 'SP', 'BOITUVA': 'SP', 'CAPIVARI': 'SP',
    'CACHOEIRA PAULISTA': 'SP', 'MONTE MOR': 'SP', 'APARECIDA': 'SP',
    'VARGEM GRANDE DO SUL': 'SP', 'OSVALDO CRUZ': 'SP', 'JABOTICABAL': 'SP',
    'ITUVERAVA': 'SP', 'AVARE': 'SP', 'MOCOCA': 'SP', 'CATANDUVA': 'SP',
    'IRACEMAPOLIS': 'SP', 'VARGEM GRANDE PAULISTA': 'SP', 'PEDERNEIRAS': 'SP',
    'DESCALVADO': 'SP', 'JAMUNDI': 'CO', # Jamundi é na Colômbia, então movido para internacional
    'LEME': 'SP', 'BARIRI': 'SP', 'PARAIBUNA': 'SP', 'FERNANDOPOLIS': 'SP',
    'GUARIBA': 'SP', 'CARAGUATATUBA': 'SP', 'RIO GRANDE DA SERRA': 'SP',
    'AGUAI': 'SP', 'SANTA CRUZ DO RIO PARDO': 'SP', 'PORTO FELIZ': 'SP',
    'DUMONT': 'SP', 'PIRATININGA': 'SP', 'MIRANDOPOLIS': 'SP', 'SOCORRO': 'SP',
    'CERQUILHO': 'SP', 'ARTUR NOGUEIRA': 'SP', 'SANTA ROSA DE VITERBO': 'SP',
    'IPUA': 'SP', 'IBATE': 'SP', 'SANTA BRANCA': 'SP', 'MIRASSOL': 'SP',
    'MATHEU': 'SP', 'CABREUVA': 'SP', 'MONTE AZUL PAULISTA': 'SP',
    'AGUAS DE SAO PEDRO': 'SP', 'IBITINGA': 'SP', 'NAZARE PAULISTA': 'SP',
    'PALMITAL': 'SP', 'JALES': 'SP', 'TUPA': 'SP', 'ITAPOLIS': 'SP',
    'CEDRAL': 'SP', 'PIRANGI': 'SP', 'BOM DESPACHO': 'MG',
    'CONGONHAS': 'MG', 'PEDRO LEOPOLDO': 'MG', 'ARAGUARI': 'MG',
    'PONTE NOVA': 'MG', 'ALFENAS': 'MG', 'PASSOS': 'MG', 'SAO SEBASTIAO DO PARAISO': 'MG',
    'MURIAE': 'MG', 'CAMPO BELO': 'MG', 'TRES CORACOES': 'MG', 'SABARA': 'MG',
    'CAMPANHA': 'MG', 'PERDOES': 'MG', 'SAO GOTARDO': 'MG',
    'DIVINOLANDIA': 'MG', 'TRES MARIAS': 'MG', 'NEROPOLIS': 'GO',
    'FORMIGA': 'MG', 'CASSIA': 'MG', 'SAO LOURENCO': 'MG', 'PATROCINIO': 'MG',
    'CACHOEIRA DE MINAS': 'MG', 'GUAXUPE': 'MG', 'JOAIMA': 'MG',
    'GUANHAES': 'MG', 'JACUTINGA': 'MG', 'JUATUBA': 'MG', 'BOCAIUVA': 'MG',
    'LEOPOLDINA': 'MG', 'PARAGUACU': 'MG', 'BRASOPOLIS': 'MG', 'CONGONHAL': 'MG',
    'VASSOURAS': 'RJ', 'MONTE APRAZIVEL': 'MG', 'MACHADO': 'MG',
    'AGUAS DE LINDOIA': 'SP', # Cidade de SP, não MG
    'SANTOS DUMONT': 'MG', 'BARAO DE COCAIS': 'MG', 'OURO BRANCO': 'MG',
    'OLIVEIRA': 'MG', 'TRES PONTAS': 'MG', 'ITURAMA': 'MG', 'NOVA SERRANA': 'MG',
    'LAGOA DA PRATA': 'MG', 'RIO CASCA': 'MG', 'UNAI': 'MG', 'AREADO': 'MG',
    'CAPELINHA': 'MG', 'PITANGUI': 'MG', 'BARBACENA': 'MG', 'MONTES CLAROS': 'MG',
    'JUIZ DE FORA': 'MG', 'POCOS DE CALDAS': 'MG', 'NOVA LIMA': 'MG',
    'OURO PRETO': 'MG', 'SETE LAGOAS': 'MG', 'UBERLANDIA': 'MG',
    'CRUZEIRO': 'SP', # Cidade de SP, não MG
    'VOLTA REDONDA': 'RJ', 'NITEROI': 'RJ', 'DUQUE DE CAXIAS': 'RJ',
    'NOVA IGUACU': 'RJ', 'MACAE': 'RJ', 'RIO DAS OSTRAS': 'RJ',
    'SAO JOAO DE MERITI': 'RJ', 'MAGE': 'RJ', 'CABO FRIO': 'RJ',
    'BARRA MANSA': 'RJ', 'PETROPOLIS': 'RJ', 'RIO DE JANEIRO': 'RJ',
    'ARARUAMA': 'RJ', 'ITABORAI': 'RJ', 'CACHOEIRAS DE MACACU': 'RJ',
    'MIRACEMA': 'RJ', 'PINHEIRAL': 'RJ', 'RIO BONITO': 'RJ',
    'BELFORD ROXO': 'RJ', 'VITORIA': 'ES', 'VILA VELHA': 'ES',
    'GUARAPARI': 'ES', 'CARIACICA': 'ES', 'ARACRUZ': 'ES',
    'COLATINA': 'ES', 'IBIRACU': 'ES', 'LINHARES': 'ES',
    'JAGUARE': 'ES', 'VILHENA': 'RO', 'PORTO VELHO': 'RO', 'RIO BRANCO': 'AC',
    'MANAUS': 'AM', 'BELEM': 'PA', 'SANTAREM': 'PA', 'CASTANHAL': 'PA',
    'MARABA': 'PA', 'TUCURUI': 'PA', 'SAO LUIS': 'MA', 'IMPERATRIZ': 'MA',
    'BALSAS': 'MA', 'TIMON': 'MA', 'MACEIO': 'AL', 'DELMIRO GOUVEIA': 'AL',
    'ARACAJU': 'SE', 'SALVADOR': 'BA', 'LAURO DE FREITAS': 'BA',
    'ITABUNA': 'BA', 'GUANAMBI': 'BA', 'VALENCA': 'BA', 'MUCURI': 'BA',
    'PORTO SEGURO': 'BA', 'ILHEUS': 'BA', 'CARUARU': 'PE', 'EUNAPOLIS': 'BA', # Eunaópolis é BA
    'JOAO PESSOA': 'PB', 'PATOS': 'PB', 'SAO LOURENCO DA MATA': 'PE', # São Lourenço da Mata é PE
    'RECIFE': 'PE', 'OLINDA': 'PE', 'CABO DE SANTO AGOSTINHO': 'PE',
    'JABOATAO DOS GUARARAPES': 'PE', 'PETROLINA': 'PE', 'FEIRA DE SANTANA': 'BA', # Feira de Santana é BA
    'SALVADOR': 'BA', # Certificar que Salvador está lá
    'GOIANIA': 'GO', 'BRASILIA': 'DF', 'ANAPOLIS': 'GO', 'JATAI': 'GO',
    'MINEIROS': 'GO', 'GOIANESIA': 'GO', 'APARECIDA DE GOIANIA': 'GO',
    'ITUMBIARA': 'GO', 'RIO VERDE': 'GO', 'CATALAO': 'GO',
    'TERESINA': 'PI', 'FORTALEZA': 'CE', 'CRATO': 'CE', 'ICO': 'CE',
    'NATAL': 'RN', 'PORTO ALEGRE': 'RS', 'CAXIAS DO SUL': 'RS',
    'CANOAS': 'RS', 'SANTA LUZIA': 'MG', # Santa Luzia é MG
    'SANTA MARIA': 'RS', 'NOVO HAMBURGO': 'RS', 'SAO GABRIEL': 'RS',
    'PELOTAS': 'RS', 'RIO GRANDE': 'RS', 'GRAVATAI': 'RS',
    'SANTA CRUZ DO SUL': 'RS', 'SOLEDAD': 'RS', 'TAPEJARA': 'RS',
    'CACHOEIRINHA': 'RS', 'SANTO ANGELO': 'RS', 'PANAMBI': 'RS',
    'CANDELARIA': 'RS', 'ERECHIM': 'RS', 'CARAZINHO': 'RS',
    'BENTO GONCALVES': 'RS', 'ARROIO DO MEIO': 'RS', 'VENANCIO AIRES': 'RS',
    'TUPANCIRETA': 'RS', 'IVOTI': 'RS',
    'CURITIBA': 'PR', 'LONDRINA': 'PR', 'MARINGA': 'PR',
    'TOLEDO': 'PR', 'PONTA GROSSA': 'PR', 'PAULINIA': 'SP', # Paulinia é SP, não PR
    'CAMPO MOURAO': 'PR', 'CAMBE': 'PR', 'QUATRO BARRAS': 'PR',
    'BANDEIRANTES': 'PR', 'CASTRO': 'PR', 'ALMIRANTE TAMANDARE': 'PR',
    'IBIPORA': 'PR', 'PARANAGUA': 'PR', 'DOIS VIZINHOS': 'PR',
    'MISSAL': 'PR', 'COLOMBO': 'PR', 'MARIALVA': 'PR',
    'FRANCISCO BELTRAO': 'PR', 'CORNELIO PROCOPIO': 'PR', 'SAO JOSE DOS PINHAIS': 'PR',
    'FLORIANOPOLIS': 'SC', 'JOINVILLE': 'SC', 'BLUMENAU': 'SC',
    'BALNEARIO CAMBORIU': 'SC', 'ITAJAI': 'SC', 'CRICIUMA': 'SC',
    'TUBARAO': 'SC', 'IMBITUBA': 'SC', 'CHAPECO': 'SC', 'LAGES': 'SC',
    'CAMBORIU': 'SC', 'ITAPEMA': 'SC', 'LUIZ ALVES': 'SC',
    'CACADOR': 'SC', 'VIDEIRA': 'SC', 'LAURO MULLER': 'SC',
    'ITUPORANGA': 'SC', 'CAMPO GRANDE': 'MS', 'DOURADOS': 'MS', 'TRES LAGOAS': 'MS',
    'NOVA ANDRADINA': 'MS', 'MARACAJU': 'MS', 'VARZEA GRANDE': 'MT',
    'ALTA FLORESTA': 'MT'
}


# Lista de cidades internacionais
cidades_internacionais = [
    'BUENOS AIRES', 'BOGOTA', 'LIMA', 'CIUDAD DE MEXICO', 'CARTAGENA', 'CALI',
    'LA PLATA', 'MEDELLIN', 'ROSARIO', 'BUCARAMANGA', 'PUEBLA', 'VICENTE LOPEZ',
    'CORDOBA', 'MENDOZA', 'MAR DEL PLATA', 'SANTA FE', 'SALTA', 'QUILMES',
    'SAN MIGUEL DE TUCUMAN', 'CHIA', 'MORON', 'LOMAS DE ZAMORA', 'MONTERREY',
    'TIGRE', 'ALMIRANTE BROWN', 'GENERAL SAN MARTIN', 'SAN RAFAEL', 'RAMOS MEJIA',
    'AVELLANEDA', 'CALLAO', 'ECATEPEC', 'TORREON', 'SAN MIGUEL', 'SYDNEY',
    'MONTREAL', 'MONTERIA', 'VINA DEL MAR', 'MONTE GRANDE', 'BECCAR', 'MAIPU',
    'BERAZATEGUI', 'BERNAL', 'SANTA ANITA', 'MIRAFLORES', 'JUNIN', 'PIURA',
    'WILDE', 'CARACAS', 'EL PALOMAR', 'HUIXQUILUCAN', 'PACHUCA DE SOTO', 'TANDIL',
    'XALAPA', 'BANFIELD', 'MERLO', 'VERA CRUZ', 'TULTITLAN', 'HERMOSILLO',
    'NEZAHUALCOYOTL', 'CASEROS', 'ENVIGADO', 'JIUTEPEC', 'TRELEW', 'SALAMANCA',
    'ESCOBAR', 'CHOLULA DE RIVA DABIA', 'CUERNAVACA', 'MERIDA', 'BARUTA',
    'VILLAHERMOSA', 'VILLA BOSCH', 'SAN PEDRO', 'SANTA CRUZ DE LA SIERRA',
    'AGUASCALIENTES', 'CORRIENTES', 'RIO CUARTO', 'TURIN', 'VILLA CONSTITUCION',
    'ESTANCIA VELHA', 'SAN CARLOS DE BARILOCHE', 'GUADALAJARA', 'ZARATE', 'BUGA',
    'SAN CRISTOBAL', 'VILLA MERCEDES', 'COACALCO DE BERRIOZABAL', 'FLORIDA', 'PANAMA',
    'OLIVOS', 'SAN LUIS', 'SAN BORJA HACIENDA', 'PALMIRA', 'NEIVA', 'ZIPAQUIRA',
    'NAUCALPAN DE JUAREZ', 'HURLINGHAM', 'HAEDO', 'LAS HERAS', 'TURBACO', 'SAN JUAN',
    'SAN JUSTO', 'CHORRILLOS', 'PUEBLO LIBRE', 'ITUZAINGO', 'TRUJILLO', 'NEUQUEN',
    'DON TORCUATO', 'METEPEC', 'DUITAMA', 'COATZACOALCOS', 'MANIZALES',
    'FLORIDABLANCA', 'ESTEIO', 'PUNTA ALTA', 'BARCARENA', 'MORELIA', 'MORENO',
    'SAN ANDRES CHOLULA', 'PACO DO LUMIAR', 'GUAIRA', 'CABEDELO',
    'LA MOLINA HACIENDA', 'PARAUAPEBAS', 'BERAZATEGUI', 'BERNAL', 'PATO BRANCO',
    'QUITOS', 'SANTIAGO DEL ESTERO', 'BUENAVISTA', 'CERETE', 'ROMA',
    'CHERRY HILL', 'SANTO TOME', 'LOS CHORROS', 'VILLA LUZURIAGA', 'LA RIOJA',
    'DUBLIN', 'CULIACAN', 'JOSE CLEMENTE PAZ', 'OLAVARRIA', 'SAN LORENZO',
    'SAN MARTIN', 'BERLIN', 'PASTO', 'ALPES', 'CHICLAYO', 'SANTA MARTA',
    'PUERTO COLOMBIA', 'MARACAIBO', 'DEL VISO', 'LA LUCILA', 'VICTORIA',
    'CAJICA', 'CHACRAS DE CORIA', 'BARANOA', 'MOSQUERA', 'SAN FRANCISCO',
    'GUATEMALA', 'VILLA NUEVA DE GUAYMALLEN', 'BENAVIDES', 'FUNZA', 'ITAGUI',
    'CIPOLETTI', 'PARANA', 'CINCO SALTOS', 'VILLA HIPODROMO', 'SABANETA',
    'VILLAGUAY', 'GRAND BOURG', 'GARIN', 'TLAJOMULCO DE ZUNIGA', 'GENERAL PACHECO',
    'TLAQUEPAQUE', 'LEON', 'JUAREZ', 'SAN NICOLAS DE LOS GARZAS', 'TECAMAC',
    'OAXACA', 'SAN LUIS POTOSI', 'LOMAS DEL MIRADOR', 'MINERAL DE LA REFORMA',
    'SANTA ISABEL', 'ORIZABA', 'VALLE DE CHALCO SOLIDARIDAD',
    'VENADO TUERTO', 'FACATATIVA', 'FUERTE GENERAL ROCA', 'CUCUTA',
    'MARACAIBO NORTE', 'SAN JOSE', 'COMODORO RIVADAVIA', 'CIUDAD GUAYANA',
    'INDEPENDENCIA', 'SINCELEJO', 'VILLA MADERO', 'COMDORO RIVADAVIA',
    'VANCOUVER', 'SANTIAGO', 'TOLUCA', 'LANUS', 'COLOMBIA', 'ZAPOPAN', 'JAMUNDI' # Adicionei Jamundi aqui
]

# Criar um novo dicionário de mapeamento final para usar com .replace()
mapeamento_final = {}

# Mapear as cidades brasileiras para seus estados (UFs)
for cidade, estado in mapeamento_cidades_br_estados.items():
    mapeamento_final[cidade] = estado

# Adicionar as cidades internacionais ao mapeamento com o valor 'INTL'
for cidade in cidades_internacionais:
    mapeamento_final[cidade] = 'INTL'

# Aplicar o mapeamento na coluna 'cidade_candidato'
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace(mapeamento_final)

# Para qualquer cidade que não foi explicitamente mapeada (nem para UF, nem para 'INTL'),
# assumimos que são outras cidades brasileiras e atribuímos 'OUTROS_BR'.
# Esta linha deve vir DEPOIS das substituições de UF e INTL.
estados_existentes = list(mapeamento_cidades_br_estados.values())
if 'INTL' not in estados_existentes: # Adiciona 'INTL' temporariamente para a verificação
    estados_existentes.append('INTL')

arquivo.loc[
    ~arquivo['cidade_candidato'].isin(estados_existentes),
    'cidade_candidato'
] = 'OUTROS_BR'

# %%
arquivo['cidade_candidato'].value_counts()

# %%
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace('SP', 0)
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace('OUTROS_BR', 1)
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace('INTL', 2)
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace('RJ', 3)
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace('PR', 4)
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace('MG', 5)
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace('BA', 6)
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace('RS', 7)
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace('SC', 8)
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace('ES', 9)
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace('PE', 10)
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace('DF', 11)
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace('GO', 12)
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace('RN', 13)
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace('CE', 14)
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace('PA', 15)
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace('MS', 16)
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace('MA', 17)
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace('AM', 18)
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace('PB', 19)
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace('SE', 20)
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace('AL', 21)
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace('PI', 22)
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace('RO', 23)
arquivo['cidade_candidato'] = arquivo['cidade_candidato'].replace('MT', 24)

# %% [markdown]
# # 12 PADRONIZANDO CARGO VAGA

# %%
arquivo['cargo_vaga'].value_counts()

# %%
arquivo['cargo_vaga'] = arquivo['cargo_vaga'].replace('TRAINEE', 0)
arquivo['cargo_vaga'] = arquivo['cargo_vaga'].replace('GERENTE', 1)
arquivo['cargo_vaga'] = arquivo['cargo_vaga'].replace('ANALISTA COMERCIAL', 2)
arquivo['cargo_vaga'] = arquivo['cargo_vaga'].replace('ANALISTA DE TI', 3)

# %% [markdown]
# # 13 PADRONIZANDO NIVEL VAGA

# %%
arquivo['nivel_vaga'].value_counts()

# %%
arquivo['nivel_vaga'] = arquivo['nivel_vaga'].replace('JUNIOR/TRAINEE', 0)

# %% [markdown]
# # 14 PADRONIZANDO NIVEL FORMAÇÂO

# %%
arquivo['formacao_vaga'].value_counts()

# %%
arquivo['formacao_vaga'] = arquivo['formacao_vaga'].replace('FORMACAO SUPERIOR (CURSANDO)', 1)
arquivo['formacao_vaga'] = arquivo['formacao_vaga'].replace('FORMACAO SUPERIOR COMPLETA', 2)

# %% [markdown]
# # 15 salvando o arqvuio final

# %%
arquivo.to_csv('C:/excel/Candidatos/canditatosfinal', index=False)
